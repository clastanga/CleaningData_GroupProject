# %%
#sci_data = pd.read_csv('/Users/claudia/Desktop/data_scientist_final.csv')

# %%
#ana_data = pd.read_csv('/Users/claudia/Desktop/data_analyst_final.csv')

# %%
#engi_data = pd.read_csv('/Users/claudia/Desktop/data_engineer_final.csv')

# %%
#sci_data.shape

# %%
import pandas as pd
import numpy as np
import re
from matplotlib import pyplot as plt
import itertools
plt.style.use('ggplot')
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input

password = getpass.getpass()
engine = f'mysql+pymysql://root:password@localhost/datajobs'
# Out:
# ········

# %%
#top 10 industries for Data Scientist, Analyst, Engineer
sci_data_query1 = '''select *
from data_scientist_final 
order by num_positions Desc
limit 10'''

ana_data_query1 = '''select *
from data_analyst_final 
order by num_positions Desc
limit 10;'''

engi_query1 = '''select *
from data_analyst_final 
order by num_positions Desc
limit 10'''

# %%
sci_top_ten = pd.read_sql(sci_data_query1, engine) #turn the query into a pandas dataframe
sci_top_ten
# Out:
#                               industry  num_positions      size  \
# 0                             internet            157    medium
# 1                        biotechnology            154       big
# 2                    computer software            105    medium
# 3                      pharmaceuticals             79  very big
# 4                   financial services             71       big
# 5  information technology and services             70    medium
# 6              staffing and recruiting             58    medium
# 7                             research             42       big
# 8                               retail             40  very big
# 9               hospital & health care             30  very big
#
#                                          description state  rank_by_size
# 0  Vungle's mission is to deliver the most engagi...    CA             1
# 1  Job Summary:\nGlobal Product Support is a key ...    CA             1
# ...

# %%
sci_top_ten = sci_top_ten.drop(['description','rank_by_size'], axis=1)
sci_top_ten
# Out:
#                               industry  num_positions      size state
# 0                             internet            157    medium    CA
# 1                        biotechnology            154       big    CA
# 2                    computer software            105    medium    GA
# 3                      pharmaceuticals             79  very big    MA
# 4                   financial services             71       big    GA
# 5  information technology and services             70    medium    GA
# 6              staffing and recruiting             58    medium    GA
# 7                             research             42       big    GA
# 8                               retail             40  very big    GA
# 9               hospital & health care             30  very big    GA

# %%
top_ten_industry.rename(columns={"industry": "Data Scientist", "industry": "Data Analyst", "industry": "Engineer"}, inplace=True)

# %%
anst_top_ten = pd.read_sql(ana_data_query1, engine) #turn the query into a pandas dataframe
sci_top_ten
# Out:
#                               industry  num_positions      size  \
# 0                             internet            157    medium
# 1                        biotechnology            154       big
# 2                    computer software            105    medium
# 3                      pharmaceuticals             79  very big
# 4                   financial services             71       big
# 5  information technology and services             70    medium
# 6              staffing and recruiting             58    medium
# 7                             research             42       big
# 8                               retail             40  very big
# 9               hospital & health care             30  very big
#
#                                          description state  rank_by_size
# 0  Vungle's mission is to deliver the most engagi...    CA             1
# 1  Job Summary:\nGlobal Product Support is a key ...    CA             1
# ...

# %%
anst_top_ten = anst_top_ten.drop(['description','rank_by_size'], axis=1)
anst_top_ten
# Out:
#                               industry  num_positions      size state
# 0                   financial services             57  very big    MA
# 1                             internet             38       big    MA
# 2  information technology and services             29  very big    DC
# 3                     higher education             26  very big    GA
# 4                    computer software             25  very big    CA
# 5                              banking             25  very big    IL
# 6               hospital & health care             20       big    MA
# 7                management consulting             20     small    NY
# 8                      defense & space             11       big    CA
# 9               commercial real estate             11  very big    IL

# %%
engi_top_ten = pd.read_sql(engi_query1, engine) #turn the query into a pandas dataframe
sci_top_ten
# Out:
#                               industry  num_positions      size  \
# 0                             internet            157    medium
# 1                        biotechnology            154       big
# 2                    computer software            105    medium
# 3                      pharmaceuticals             79  very big
# 4                   financial services             71       big
# 5  information technology and services             70    medium
# 6              staffing and recruiting             58    medium
# 7                             research             42       big
# 8                               retail             40  very big
# 9               hospital & health care             30  very big
#
#                                          description state  rank_by_size
# 0  Vungle's mission is to deliver the most engagi...    CA             1
# 1  Job Summary:\nGlobal Product Support is a key ...    CA             1
# ...

# %%
engi_top_ten = engi_top_ten.drop(['description','rank_by_size'], axis=1)
engi_top_ten
# Out:
#                               industry  num_positions      size state
# 0                   financial services             57  very big    MA
# 1                             internet             38       big    MA
# 2  information technology and services             29  very big    DC
# 3                     higher education             26  very big    GA
# 4                    computer software             25  very big    CA
# 5                              banking             25  very big    IL
# 6               hospital & health care             20       big    MA
# 7                management consulting             20     small    NY
# 8                      defense & space             11       big    CA
# 9               commercial real estate             11  very big    IL

# %%
top_ten_industry = pd.concat([sci_top_ten, anst_top_ten, engi_top_ten], axis=1)

# %%
top_ten_industry
# Out:
#                               industry  num_positions      size state  \
# 0                             internet            157    medium    CA
# 1                        biotechnology            154       big    CA
# 2                    computer software            105    medium    GA
# 3                      pharmaceuticals             79  very big    MA
# 4                   financial services             71       big    GA
# 5  information technology and services             70    medium    GA
# 6              staffing and recruiting             58    medium    GA
# 7                             research             42       big    GA
# 8                               retail             40  very big    GA
# 9               hospital & health care             30  very big    GA
#
#                               industry  num_positions      size state  \
# 0                   financial services             57  very big    MA
# ...

# %%
top_ten_industry.columns
# Out:
# Index(['industry', 'num_positions', 'size', 'state', 'industry',
#        'num_positions', 'size', 'state', 'industry', 'num_positions', 'size',
#        'state'],
#       dtype='object')

# %%
top_ten_industry.rename(columns={"industry": "Data Scientist", "industry": "Data Analyst", "industry": "Engineer"}, inplace=True)

# %%
#type of industries, small companies
sci_data_query2 = '''select *
from data_scientist_final
where size like 'small' 
limit 10'''

# %%
sci_data.head()

# %%
#top 10 industries for Data

# %%
#type of industries, small companies

# %%
sci_small = pd.read_sql(sci_data_query2, engine) #turn the query into a pandas dataframe
sci_small

# %%
sns.set_style("darkgrid") #whitegrid,dark
sns.set_context("notebook")
sns.set_context(font_scale=2, rc={'font.size':15,'axes.labelsize':15})

Sci_top10= sns.factorplot(x= "num_positions", y="industry", hue= 'size', data=sci_top_ten, size = 10,
                          kind='bar', palette='Spectral', edgecolor = 'w', legend_out=False)
plt.title('Top 10 industries looking for Data Scientists')
plt.show()
